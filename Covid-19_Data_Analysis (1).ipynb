# %% [markdown]
# # Covid-19 Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\SNEGHAL\Desktop\covid19_italy_region.csv")

# %%
data.head()
# Out:
#     SNo                 Date Country  RegionCode      RegionName   Latitude  \
# 0  3990  2020-09-01T17:00:00     ITA          13         Abruzzo  42.351222
# 1  3991  2020-09-01T17:00:00     ITA          17      Basilicata  40.639471
# 2  3992  2020-09-01T17:00:00     ITA          18        Calabria  38.905976
# 3  3993  2020-09-01T17:00:00     ITA          15        Campania  40.839566
# 4  3994  2020-09-01T17:00:00     ITA           8  Emilia-Romagna  44.494367
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                    29                      1
# 1  15.805148                     1                      1
# 2  16.594402                    22                      0
# 3  14.250850                   143                      6
# 4  11.341721                   106                      9
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                         30              376                   406
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.tail()
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 2032  6022  2020-12-06T17:00:00     ITA          19        Sicilia  38.115697
# 2033  6023  2020-12-06T17:00:00     ITA           9        Toscana  43.769231
# 2034  6024  2020-12-06T17:00:00     ITA          10         Umbria  43.106758
# 2035  6025  2020-12-06T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 2036  6026  2020-12-06T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 2032  13.362357                  1367                    213
# 2033  11.255889                  1360                    252
# 2034  12.388247                   332                     60
# 2035   7.320149                   102                      8
# 2036  12.338452                  2508                    308
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# ...

# %%
data.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  2037.000000  2037.000000  2037.000000  2037.000000
# mean   5008.000000    11.857143    43.046293    12.225955
# std     588.175569     6.275339     2.489392     2.659601
# min    3990.000000     1.000000    38.115697     7.320149
# 25%    4499.000000     7.000000    41.125596    11.121231
# 50%    5008.000000    12.000000    43.616760    12.388247
# 75%    5517.000000    17.000000    45.434905    13.768136
# max    6026.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           2037.000000            2037.000000                2037.000000
# mean             684.592538              72.923417                 757.515955
# std             1229.984339             130.470668                1357.218668
# min                1.000000               0.000000                   1.000000
# ...

# %%
data.isnull().sum()
# Out:
# SNo                          0
# Date                         0
# Country                      0
# RegionCode                   0
# RegionName                   0
# Latitude                     0
# Longitude                    0
# HospitalizedPatients         0
# IntensiveCarePatients        0
# TotalHospitalizedPatients    0
# HomeConfinement              0
# CurrentPositiveCases         0
# NewPositiveCases             0
# Recovered                    0
# Deaths                       0
# TotalPositiveCases           0
# TestsPerformed               0
# dtype: int64

# %% [markdown]
# # relating the variables with scatterplots

# %%
sns.relplot(x="TotalPositiveCases", y="Recovered",data=data)

# %%
sns.relplot(x="TotalPositiveCases", y="Deaths",data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='HomeConfinement',y='TotalPositiveCases',kind='line',data=data)

# %%
sns.relplot(x='HomeConfinement',y='Recovered',kind='line',data=data)
